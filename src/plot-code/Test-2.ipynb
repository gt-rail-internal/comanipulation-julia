# %%
import numpy as np
import itertools as IT
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

user_id = 203

path = "/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/experiment_run.csv".format(user_id)

obj = pd.read_csv(path)

#obj.loc[0]
obj
# Out:
#     Part:  Method:              Trajectories:                  Problem:  \
# 0       1  NOMINAL  traj_nominal_1_A_D_62.txt  958169 + 946083 - 574997
# 1       1  NOMINAL     traj_nominal_3_D_B.txt  333344 - 879850 + 377442
# 2       1  NOMINAL     traj_nominal_2_D_E.txt  230026 - 507889 + 827710
# 3       1  NOMINAL     traj_nominal_3_C_B.txt  980925 + 329548 + 101681
# 4       1     DIST     traj_1_A_D_62_dist.txt  499579 + 542054 + 732242
# 5       1     DIST        traj_3_D_B_dist.txt  890187 + 578690 - 623120
# 6       1     DIST        traj_3_C_B_dist.txt  187464 - 752537 + 742286
# 7       1     DIST        traj_2_D_E_dist.txt  285812 - 264752 - 605641
# 8       1   COMOTO             traj_2_D_E.txt  164936 - 167669 + 731913
# 9       1   COMOTO             traj_3_D_B.txt  794392 + 689096 + 562817
# 10      1   COMOTO          traj_1_A_D_62.txt  345202 - 466801 - 477575
# 11      1   COMOTO             traj_3_C_B.txt  532963 - 449553 + 300722
# 12      2  NOMINAL     traj_nominal_2_E_C.txt  115027 + 298973 - 593393
# 13      2   COMOTO             traj_2_E_C.txt  806137 - 291813 - 693148
# 14      2     DIST        traj_2_E_C_dist.txt  976188 - 384005 + 610447
# 15      2   COMOTO             traj_2_E_B.txt  961690 - 114840 + 181422
# 16      2     DIST        traj_2_E_B_dist.txt  880641 + 841326 + 985138
# 17      2  NOMINAL     traj_nominal_2_E_B.txt  862269 + 371130 + 886571
# 18      2  NOMINAL  traj_nominal_3_A_C_52.txt  444228 - 239730 - 124758
# 19      2   COMOTO          traj_3_A_C_52.txt  952451 - 984740 - 244622
# 20      2     DIST     traj_3_A_C_52_dist.txt  194693 - 681384 - 957467
# 21      2     DIST        traj_2_A_B_dist.txt  841428 + 697920 - 265213
# 22      2  NOMINAL     traj_nominal_2_A_B.txt  741746 + 514228 - 106113
# 23      2   COMOTO             traj_2_A_B.txt  463054 - 715226 - 207964
#
#         Time:   Solution:   Accuracy:
# 0   26.759436     1329255        True
# 1   24.269242     -169064        True
# 2   22.335938      549847        True
# 3   22.432575     1412154        True
# 4   19.171897     1773875        True
# 5   19.949135      845757        True
# 6   23.807294      177213        True
# 7   22.048427     -584581        True
# 8   19.934583      729180        True
# 9   19.990442     2046305        True
# 10  19.376063     -599174        True
# 11  16.972896      384132        True
# 12  20.709038     -179393        True
# 13  22.861553     -178824        True
# 14  18.932681     1202630        True
# 15  22.958089     1028272        True
# 16  20.576918    22707105       False
# 17  19.289829    22119970       False
# 18  20.456900       79740        True
# 19  19.709555     -276911        True
# 20  22.999701    -1444158        True
# 21  16.839826     1274135        True
# 22  18.723604   111149861       False
# 23  14.813113     -460136        True
