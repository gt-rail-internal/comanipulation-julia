# %%
import numpy as np
import itertools as IT
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure


user_id = 206

# file_name1 = "run_" + str(16)
# file_name2 = "run_" + str(20)
# file_name3 = "run_" + str(21)

# file_name1 = "run_" + str(2)
# file_name2 = "run_" + str(4)
# file_name3 = "run_" + str(11)

file_name1 = "run_" + str(1)
file_name2 = "run_" + str(5)
file_name3 = "run_" + str(6)

# file_name1 = "run_" + str(19)
# file_name2 = "run_" + str(20)
# file_name3 = "run_" + str(21)

tag = 'User-{}'.format(user_id)
logdir_pathed1 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric1_"+file_name1)
logdir_pathed2 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric1_"+file_name2)
logdir_pathed3 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric1_"+file_name3)

obj1 = pd.read_csv(logdir_pathed1)
obj2 = pd.read_csv(logdir_pathed2)
obj3 = pd.read_csv(logdir_pathed3)

# obj = obj.transform(lambda x: x.iloc[1].astype(str).replace("run time: ", ""))
x1 = obj1["Run Time: "]
y1 = obj1["Distance: "]
x2 = obj2["Run Time: "]
y2 = obj2["Distance: "]
x3 = obj3["Run Time: "]
y3 = obj3["Distance: "]

SMALL_SIZE = 8
MEDIUM_SIZE = 14
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

fig = figure(figsize=(24, 15))

# plt.xlim(0,1.2)
# plt.ylim(0,1.2)

plt.plot(x1, y1, color='red', label="NOMINAL", linewidth=2, alpha=1)
plt.plot(x2, y2, color='green', label="DISTANCE", linewidth=2, alpha=1)
plt.plot(x3, y3, color='navy', label="COMOTO", linewidth=2, alpha=1)

plt.title("Metric 1")
plt.xlabel("Time (s)")
plt.ylabel("Distance between the robot base and the participant (m)")
plt.legend(loc="upper left", prop={'size': 14})

# plt.show()

plt.savefig('Metric_1.png')

# %%
logdir_pathed1 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric2_"+file_name1)
logdir_pathed2 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric2_"+file_name2)
logdir_pathed3 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric2_"+file_name3)


# print(logdir_pathed1)
# print(logdir_pathed2)
# print(logdir_pathed3)

obj1 = pd.read_csv(logdir_pathed1)
obj2 = pd.read_csv(logdir_pathed2)
obj3 = pd.read_csv(logdir_pathed3)

# obj = obj.transform(lambda x: x.iloc[1].astype(str).replace("run time: ", ""))
x1 = obj1["Run Time: "]
y1 = obj1["Lift State: "]
x2 = obj2["Run Time: "]
y2 = obj2["Lift State: "]
x3 = obj3["Run Time: "]
y3 = obj3["Lift State: "]

figure(figsize=(24, 15))

plt.plot(x1, y1, color='red', label="NOMINAL", linewidth=2, alpha=1)
plt.plot(x2, y2, color='green', label="DISTANCE", linewidth=2, alpha=1)
plt.plot(x3, y3, color='navy', label="COMOTO", linewidth=2, alpha=1)


plt.title("Metric 2")
plt.xlabel("Time (s)")
plt.ylabel("Lift State of the participant's hand")
plt.legend(loc="upper left", prop={'size': 14})

# plt.show()

plt.savefig('Metric_2.png')

# %%
logdir_pathed1 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric3_"+file_name1)
logdir_pathed2 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric3_"+file_name2)
logdir_pathed3 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric3_"+file_name3)


# print(logdir_pathed1)
# print(logdir_pathed2)
# print(logdir_pathed3)

obj1 = pd.read_csv(logdir_pathed1)
obj2 = pd.read_csv(logdir_pathed2)
obj3 = pd.read_csv(logdir_pathed3)

# obj = obj.transform(lambda x: x.iloc[1].astype(str).replace("run time: ", ""))
x1 = obj1["Run Time: "]
y1 = obj1["Distance: "]
x2 = obj2["Run Time: "]
y2 = obj2["Distance: "]
x3 = obj3["Run Time: "]
y3 = obj3["Distance: "]

figure(figsize=(24, 15))

plt.plot(x1, y1, color='red', label="NOMINAL", linewidth=2, alpha=1)
plt.plot(x2, y2, color='green', label="DISTANCE", linewidth=2, alpha=1)
plt.plot(x3, y3, color='navy', label="COMOTO", linewidth=2, alpha=1)


plt.title("Metric 3")
plt.xlabel("Time (s)")
plt.ylabel("Distance between the robot end effector and the participant's hand (m)")
plt.legend(loc="upper left", prop={'size': 14})

# plt.show()

plt.savefig('Metric_3.png')

# %%
logdir_pathed1 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric5_"+file_name1)
logdir_pathed2 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric5_"+file_name2)
logdir_pathed3 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric5_"+file_name3)

obj1 = pd.read_csv(logdir_pathed1)
obj2 = pd.read_csv(logdir_pathed2)
obj3 = pd.read_csv(logdir_pathed3)

# obj = obj.transform(lambda x: x.iloc[1].astype(str).replace("run time: ", ""))
x1 = obj1["Run Time: "]
y1 = obj1["Distance: "]
x2 = obj2["Run Time: "]
y2 = obj2["Distance: "]
x3 = obj3["Run Time: "]
y3 = obj3["Distance: "]

figure(figsize=(24, 15))

plt.plot(x1, y1, color='red', label="NOMINAL", linewidth=2, alpha=1)
plt.plot(x2, y2, color='green', label="DISTANCE", linewidth=2, alpha=1)
plt.plot(x3, y3, color='navy', label="COMOTO", linewidth=2, alpha=1)

plt.title("Metric 5")
plt.xlabel("Time (s)")
plt.ylabel("Distance between end effector and the manipulator base (m)")
plt.legend(loc="upper left", prop={'size': 14})

# plt.show()

plt.savefig('Metric_4.png')

# %%
import numpy as np
import itertools as IT
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure


# user_id = 205

# file_name1 = "run_" + str(22)
# file_name2 = "run_" + str(23)
# file_name3 = "run_" + str(24)
tag = 'User-{}'.format(user_id)

logdir_pathed1 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric5_"+file_name1)
logdir_pathed2 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric5_"+file_name2)
logdir_pathed3 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric5_"+file_name3)

logdir_pathed4 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric4_"+file_name1)
logdir_pathed5 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric4_"+file_name2)
logdir_pathed6 = '/home/hritiksapra/Documents/comoto.jl/src/expt_logs/user_{}/metrics/{}_{}.csv'.format(user_id,tag, "metric4_"+file_name3)

obj1 = pd.read_csv(logdir_pathed1)
obj2 = pd.read_csv(logdir_pathed2)
obj3 = pd.read_csv(logdir_pathed3)

obj4 = pd.read_csv(logdir_pathed4)
obj5 = pd.read_csv(logdir_pathed5)
obj6 = pd.read_csv(logdir_pathed6)

x1 = obj1["Run Time: "]
y1 = obj1["Distance: "]
x2 = obj2["Run Time: "]
y2 = obj2["Distance: "]
x3 = obj3["Run Time: "]
y3 = obj3["Distance: "]

x4 = obj4["Run Time: "]
y4 = obj4["Distance: "]
x5 = obj5["Run Time: "]
y5 = obj5["Distance: "]
x6 = obj6["Run Time: "]
y6 = obj6["Distance: "]

# plt.plot(x1, y1, color='red', label="NOMINAL", linewidth=2)
# plt.plot(x2, y2, color='green', label="DISTANCE", linewidth=2)
# plt.plot(x3, y3, color='navy', label="COMOTO", linewidth=2)



fig, (plt1, plt2) = plt.subplots(2)

fig.set_figheight(20)
fig.set_figwidth(20)

plt1.scatter(x1,y1, color='red', label="NOMINAL", linewidth=2, alpha=1)
plt1.scatter(x2,y2, color='green', label="DISTANCE", linewidth=2, alpha=1)
plt1.scatter(x3,y3, color='navy', label="COMOTO", linewidth=2, alpha=1)

plt1.plot(x1,y1, color='red', label="NOMINAL", linewidth=2, alpha=0.5)
plt1.plot(x2,y2, color='green', label="DISTANCE", linewidth=2, alpha=0.5)
plt1.plot(x3,y3, color='navy', label="COMOTO", linewidth=2, alpha=0.5)


plt1.set_xlabel("Time (s)")
plt1.set_ylabel("Distance between right wrist and the manipulator base (m)")
plt1.legend(loc="upper left", prop={'size': 14})

plt2.scatter(x4,y4, color='red', label="NOMINAL", linewidth=2, alpha=1)
plt2.scatter(x5,y5, color='green', label="DISTANCE", linewidth=2, alpha=1)
plt2.scatter(x6,y6, color='navy', label="COMOTO", linewidth=2, alpha=1)

plt2.plot(x4,y4, color='red', label="NOMINAL", linewidth=2, alpha=0.5)
plt2.plot(x5,y5, color='green', label="DISTANCE", linewidth=2, alpha=0.5)
plt2.plot(x6,y6, color='navy', label="COMOTO", linewidth=2, alpha=0.5)

plt2.set_xlabel("Time (s)")
plt2.set_ylabel("Distance between end effector and the manipulator base (m)")
plt2.legend(loc="upper left", prop={'size': 14})

fig.savefig('Traj_2_D_E.png')
